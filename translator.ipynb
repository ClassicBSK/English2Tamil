# %%
import numpy as np
import torch
import math
from torch import nn
import torch.nn.functional as F

def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def scaled_dot_product(q, k, v, mask=None):
    d_k = q.size()[-1]
    scaled = torch.matmul(q, k.transpose(-1, -2)) / math.sqrt(d_k)
    if mask is not None:
        scaled = scaled.permute(1, 0, 2, 3) + mask
        scaled = scaled.permute(1, 0, 2, 3)
    attention = F.softmax(scaled, dim=-1)
    values = torch.matmul(attention, v)
    return values, attention

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_sequence_length):
        super().__init__()
        self.max_sequence_length = max_sequence_length
        self.d_model = d_model

    def forward(self):
        even_i = torch.arange(0, self.d_model, 2).float()
        denominator = torch.pow(10000, even_i/self.d_model)
        position = (torch.arange(self.max_sequence_length)
                          .reshape(self.max_sequence_length, 1))
        even_PE = torch.sin(position / denominator)
        odd_PE = torch.cos(position / denominator)
        stacked = torch.stack([even_PE, odd_PE], dim=2)
        PE = torch.flatten(stacked, start_dim=1, end_dim=2)
        return PE

class SentenceEmbedding(nn.Module):
    "For a given sentence, create an embedding"
    def __init__(self, max_sequence_length, d_model, language_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN):
        super().__init__()
        self.vocab_size = len(language_to_index)
        self.max_sequence_length = max_sequence_length
        self.embedding = nn.Embedding(num_embeddings=self.vocab_size,embedding_dim= d_model)
        self.language_to_index = language_to_index
        self.position_encoder = PositionalEncoding(d_model, max_sequence_length)
        self.dropout = nn.Dropout(p=0.1)
        self.START_TOKEN = START_TOKEN
        self.END_TOKEN = END_TOKEN
        self.PADDING_TOKEN = PADDING_TOKEN
    
    def batch_tokenize(self, batch, start_token, end_token):

        def tokenize(sentence, start_token, end_token):
            sentence_word_indicies = [self.language_to_index[token] for token in list(sentence)]
            if start_token:
                sentence_word_indicies.insert(0, self.language_to_index[self.START_TOKEN])
            if end_token:
                sentence_word_indicies.append(self.language_to_index[self.END_TOKEN])
            for _ in range(len(sentence_word_indicies), self.max_sequence_length):
                sentence_word_indicies.append(self.language_to_index[self.PADDING_TOKEN])
            return torch.tensor(sentence_word_indicies)

        tokenized = []
        for sentence_num in range(len(batch)):
           tokenized.append( tokenize(batch[sentence_num], start_token, end_token) )
        tokenized = torch.stack(tokenized)
        return tokenized.to(get_device())
    
    def forward(self, x, start_token, end_token): # sentence
        x = self.batch_tokenize(x, start_token, end_token)
        x = self.embedding(x)
        pos = self.position_encoder().to(get_device())
        x = self.dropout(x + pos)
        return x


class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        self.qkv_layer = nn.Linear(d_model , 3 * d_model)
        self.linear_layer = nn.Linear(d_model, d_model)
    
    def forward(self, x, mask):
        batch_size, sequence_length, d_model = x.size()
        qkv = self.qkv_layer(x)
        qkv = qkv.reshape(batch_size, sequence_length, self.num_heads, 3 * self.head_dim)
        qkv = qkv.permute(0, 2, 1, 3)
        q, k, v = qkv.chunk(3, dim=-1)
        values, attention = scaled_dot_product(q, k, v, mask)
        values = values.permute(0, 2, 1, 3).reshape(batch_size, sequence_length, self.num_heads * self.head_dim)
        out = self.linear_layer(values)
        return out


class LayerNormalization(nn.Module):
    def __init__(self, parameters_shape, eps=1e-5):
        super().__init__()
        self.parameters_shape=parameters_shape
        self.eps=eps
        self.gamma = nn.Parameter(torch.ones(parameters_shape))
        self.beta =  nn.Parameter(torch.zeros(parameters_shape))

    def forward(self, inputs):
        dims = [-(i + 1) for i in range(len(self.parameters_shape))]
        mean = inputs.mean(dim=dims, keepdim=True)
        var = ((inputs - mean) ** 2).mean(dim=dims, keepdim=True)
        std = (var + self.eps).sqrt()
        y = (inputs - mean) / std
        out = self.gamma * y + self.beta
        return out

  
class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, hidden, drop_prob=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, hidden)
        self.linear2 = nn.Linear(hidden, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=drop_prob)

    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        return x


class EncoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, num_heads, drop_prob):
        super(EncoderLayer, self).__init__()
        self.attention = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.norm1 = LayerNormalization(parameters_shape=[d_model])
        self.dropout1 = nn.Dropout(p=drop_prob)
        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, drop_prob=drop_prob)
        self.norm2 = LayerNormalization(parameters_shape=[d_model])
        self.dropout2 = nn.Dropout(p=drop_prob)

    def forward(self, x, self_attention_mask):
        residual_x = x.clone()
        x = self.attention(x, mask=self_attention_mask)
        x = self.dropout1(x)
        x = self.norm1(x + residual_x)
        residual_x = x.clone()
        x = self.ffn(x)
        x = self.dropout2(x)
        x = self.norm2(x + residual_x)
        return x
    
class SequentialEncoder(nn.Sequential):
    def forward(self, *inputs):
        x, self_attention_mask  = inputs
        for module in self._modules.values():
            x = module(x, self_attention_mask)
        return x

class Encoder(nn.Module):
    def __init__(self, 
                 d_model, 
                 ffn_hidden, 
                 num_heads, 
                 drop_prob, 
                 num_layers,
                 max_sequence_length,
                 language_to_index,
                 START_TOKEN,
                 END_TOKEN, 
                 PADDING_TOKEN):
        super().__init__()
        self.sentence_embedding = SentenceEmbedding(max_sequence_length, d_model, language_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.layers = SequentialEncoder(*[EncoderLayer(d_model, ffn_hidden, num_heads, drop_prob)
                                      for _ in range(num_layers)])

    def forward(self, x, self_attention_mask, start_token, end_token):
        x = self.sentence_embedding(x, start_token, end_token)
        x = self.layers(x, self_attention_mask)
        return x


class MultiHeadCrossAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        self.kv_layer = nn.Linear(d_model , 2 * d_model)
        self.q_layer = nn.Linear(d_model , d_model)
        self.linear_layer = nn.Linear(d_model, d_model)
    
    def forward(self, x, y, mask):
        batch_size, sequence_length, d_model = x.size() # in practice, this is the same for both languages...so we can technically combine with normal attention
        kv = self.kv_layer(x)
        q = self.q_layer(y)
        kv = kv.reshape(batch_size, sequence_length, self.num_heads, 2 * self.head_dim)
        q = q.reshape(batch_size, sequence_length, self.num_heads, self.head_dim)
        kv = kv.permute(0, 2, 1, 3)
        q = q.permute(0, 2, 1, 3)
        k, v = kv.chunk(2, dim=-1)
        values, attention = scaled_dot_product(q, k, v, mask) # We don't need the mask for cross attention, removing in outer function!
        values = values.permute(0, 2, 1, 3).reshape(batch_size, sequence_length, d_model)
        out = self.linear_layer(values)
        return out


class DecoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, num_heads, drop_prob):
        super(DecoderLayer, self).__init__()
        self.self_attention = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.layer_norm1 = LayerNormalization(parameters_shape=[d_model])
        self.dropout1 = nn.Dropout(p=drop_prob)

        self.encoder_decoder_attention = MultiHeadCrossAttention(d_model=d_model, num_heads=num_heads)
        self.layer_norm2 = LayerNormalization(parameters_shape=[d_model])
        self.dropout2 = nn.Dropout(p=drop_prob)

        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, drop_prob=drop_prob)
        self.layer_norm3 = LayerNormalization(parameters_shape=[d_model])
        self.dropout3 = nn.Dropout(p=drop_prob)

    def forward(self, x, y, self_attention_mask, cross_attention_mask):
        _y = y.clone()
        y = self.self_attention(y, mask=self_attention_mask)
        y = self.dropout1(y)
        y = self.layer_norm1(y + _y)

        _y = y.clone()
        y = self.encoder_decoder_attention(x, y, mask=cross_attention_mask)
        y = self.dropout2(y)
        y = self.layer_norm2(y + _y)

        _y = y.clone()
        y = self.ffn(y)
        y = self.dropout3(y)
        y = self.layer_norm3(y + _y)
        return y


class SequentialDecoder(nn.Sequential):
    def forward(self, *inputs):
        x, y, self_attention_mask, cross_attention_mask = inputs
        for module in self._modules.values():
            y = module(x, y, self_attention_mask, cross_attention_mask)
        return y

class Decoder(nn.Module):
    def __init__(self, 
                 d_model, 
                 ffn_hidden, 
                 num_heads, 
                 drop_prob, 
                 num_layers,
                 max_sequence_length,
                 language_to_index,
                 START_TOKEN,
                 END_TOKEN, 
                 PADDING_TOKEN):
        super().__init__()
        self.sentence_embedding = SentenceEmbedding(max_sequence_length, d_model, language_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.layers = SequentialDecoder(*[DecoderLayer(d_model, ffn_hidden, num_heads, drop_prob) for _ in range(num_layers)])

    def forward(self, x, y, self_attention_mask, cross_attention_mask, start_token, end_token):
        y = self.sentence_embedding(y, start_token, end_token)
        y = self.layers(x, y, self_attention_mask, cross_attention_mask)
        return y


class Transformer(nn.Module):
    def __init__(self, 
                d_model, 
                ffn_hidden, 
                num_heads, 
                drop_prob, 
                num_layers,
                max_sequence_length, 
                ta_vocab_size,
                eng_to_ind,
                tam_to_ind,
                START_TOKEN, 
                END_TOKEN, 
                PADDING_TOKEN
                ):
        super().__init__()
        self.encoder = Encoder(d_model, ffn_hidden, num_heads, drop_prob, num_layers, max_sequence_length, eng_to_ind, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.decoder = Decoder(d_model, ffn_hidden, num_heads, drop_prob, num_layers, max_sequence_length, tam_to_ind, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.linear = nn.Linear(d_model, ta_vocab_size)
        self.device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    def forward(self, 
                x, 
                y, 
                encoder_self_attention_mask=None, 
                decoder_self_attention_mask=None, 
                decoder_cross_attention_mask=None,
                enc_start_token=False,
                enc_end_token=False,
                dec_start_token=False, # We should make this true
                dec_end_token=False): # x, y are batch of sentences
        x = self.encoder(x, encoder_self_attention_mask, start_token=enc_start_token, end_token=enc_end_token)
        out = self.decoder(x, y, decoder_self_attention_mask, decoder_cross_attention_mask, start_token=dec_start_token, end_token=dec_end_token)
        out = self.linear(out)
        return out
    

import torch
import numpy
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torch.nn as nn

engfile='train.en'
tamfile='train.ta'
START_TOKEN='<START>'
PADDING_TOKEN='<PAD>'
END_TOKEN='<END>'
max_seq_len=300

with open(engfile,encoding='utf8') as file:
    engsentences=file.readlines()
with open(tamfile,encoding='utf8') as file:
    tamsentences=file.readlines()

from torch import nn



engsentences=engsentences[:100]
engsentences=[sentence.rstrip('\n') for sentence in engsentences]
tamsentences=tamsentences[:100]
tamsentences=[sentence.rstrip('\n') for sentence in tamsentences]

tamvocab=sorted(list(set((''.join([str(item) for item in tamsentences])))))
tamvocab.insert(0,START_TOKEN)
tamvocab.append(PADDING_TOKEN)
tamvocab.append(END_TOKEN)
tamvocab.append('`')
tamvocab=list(set(tamvocab))
print(tamvocab)

engvocab=sorted(list(set((''.join([str(item) for item in engsentences])))))
engvocab.insert(0,START_TOKEN)
engvocab.append(PADDING_TOKEN)
engvocab.append(END_TOKEN)


ind_to_eng={t:v for t,v in enumerate(engvocab)}
eng_to_ind={v:t for t,v in enumerate(engvocab)}
ind_to_tam={t:v for t,v in enumerate(tamvocab)}
tam_to_ind={v:t for t,v in enumerate(tamvocab)}

criterian = nn.CrossEntropyLoss(ignore_index=tam_to_ind[PADDING_TOKEN],
                                reduction='none')

def is_valid_tokens(sentence, vocab):
    for token in list(set(sentence)):
        if token not in vocab:
            return False
    return True

def is_valid_length(sentence, max_seq_len):
    return len(list(sentence)) < (max_seq_len - 1)

valid_sentence_indicies = []
for index in range(len(tamsentences)):
    tamil_sentence, english_sentence = tamsentences[index], engsentences[index]
    if is_valid_length(tamil_sentence, max_seq_len) \
      and is_valid_length(english_sentence, max_seq_len) \
      and is_valid_tokens(tamil_sentence, tamvocab):
        valid_sentence_indicies.append(index)

tamsentences = [tamsentences[i] for i in valid_sentence_indicies]
engsentences = [engsentences[i] for i in valid_sentence_indicies]


d_model = 512
batch_size = 30
ffn_hidden = 2048
num_heads = 8
drop_prob = 0.1
num_layers = 1
max_sequence_length = 300
ta_vocab_size = len(tamvocab)
print(f" ta_vocab = {ta_vocab_size} tam_to_ind ={len(tam_to_ind)}")

transformer = Transformer(d_model, 
                          ffn_hidden,
                          num_heads, 
                          drop_prob, 
                          num_layers, 
                          max_sequence_length,
                          ta_vocab_size,
                          eng_to_ind,
                          tam_to_ind,
                          START_TOKEN, 
                          END_TOKEN, 
                          PADDING_TOKEN)

# When computing the loss, we are ignoring cases when the label is the padding token
for params in transformer.parameters():
    if params.dim() > 1:
        nn.init.xavier_uniform_(params)

optim = torch.optim.Adam(transformer.parameters(), lr=1e-4)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

class TextDataset(Dataset):
    def __init__(self,engsentences,tamsentences):
        self.engsentences=engsentences
        self.tamsentences=tamsentences
    
    def __len__(self):
        return len(self.engsentences)
    
    def __getitem__(self,i):
        return self.engsentences[i],self.tamsentences[i]

dataset=TextDataset(engsentences,tamsentences)

#print(dataset[50])
batch_size=3
train_loader=DataLoader(dataset,batch_size)
iterator=iter(train_loader)

for batch_num,batch in enumerate(iterator):
    print(batch)
    if batch_num>3:
        break

def tokenize(sentence,language_to_index,start_token=True,end_token=True):
    sentence_word_indices=[language_to_index[token] for token in list(sentence)]
    if start_token:
        sentence_word_indices.insert(0,language_to_index[START_TOKEN])
    if end_token:
        sentence_word_indices.append(language_to_index[END_TOKEN])
    for _ in range(len(sentence_word_indices),max_seq_len):
        sentence_word_indices.append(language_to_index[PADDING_TOKEN])
    return torch.tensor(sentence_word_indices)

eng_tokenized,tam_tokenized=[],[]
for sentence_num in range(batch_size):
    eng_sentence,ta_sentence=batch[0][sentence_num],batch[1][sentence_num]
    eng_tokenized.append(tokenize(eng_sentence,eng_to_ind,start_token=False,end_token=False))
    tam_tokenized.append(tokenize(ta_sentence,tam_to_ind,start_token=True,end_token=True))
eng_tokenized=torch.stack(eng_tokenized)
tam_tokenized=torch.stack(tam_tokenized)

neginf=-1e9
def create_masks(eng_batch,tam_batch):
    num_sentences=len(eng_batch)
    look_ahead_mask=torch.full([max_seq_len,max_seq_len],True)
    look_ahead_mask=torch.triu(look_ahead_mask,diagonal=1)
    encoder_padding_mask = torch.full([num_sentences, max_seq_len, max_seq_len] , False)
    decoder_padding_mask_self_attention = torch.full([num_sentences, max_seq_len, max_seq_len] , False)
    decoder_padding_mask_cross_attention = torch.full([num_sentences, max_seq_len, max_seq_len] , False)

    for i in range(num_sentences):
        eng_sentence_length,tam_sentence_length=len(eng_batch[i]),len(tam_batch[i])
        eng_chars_to_padding_mask=np.arange(eng_sentence_length+1,max_seq_len)
        tam_chars_to_padding_mask=np.arange(tam_sentence_length+1,max_seq_len)
        encoder_padding_mask[i, :, eng_chars_to_padding_mask] = True
        encoder_padding_mask[i, eng_chars_to_padding_mask, :] = True
        decoder_padding_mask_self_attention[i, :, tam_chars_to_padding_mask] = True
        decoder_padding_mask_self_attention[i, tam_chars_to_padding_mask, :] = True
        decoder_padding_mask_cross_attention[i, :, eng_chars_to_padding_mask] = True
        decoder_padding_mask_cross_attention[i, tam_chars_to_padding_mask, :] = True

    encoder_padding_mask[i, :, eng_chars_to_padding_mask] = True
    encoder_padding_mask[i, eng_chars_to_padding_mask, :] = True
    decoder_padding_mask_self_attention[i, :, tam_chars_to_padding_mask] = True
    decoder_padding_mask_self_attention[i, tam_chars_to_padding_mask, :] = True
    decoder_padding_mask_cross_attention[i, :, eng_chars_to_padding_mask] = True
    decoder_padding_mask_cross_attention[i, tam_chars_to_padding_mask, :] = True

    encoder_self_attention_mask = torch.where(encoder_padding_mask, neginf, 0)
    decoder_self_attention_mask =  torch.where(look_ahead_mask + decoder_padding_mask_self_attention, neginf, 0)
    decoder_cross_attention_mask = torch.where(decoder_padding_mask_cross_attention, neginf, 0)
    return encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask

class sentence_embedding(nn.Module):
    def __init__(self,max_seq_len,d_model,language_to_index,START_TOKEN,END_TOKEN,PADDING_TOKEN):
        super().__init__()
        self.vocab_size=len(language_to_index)
        self.max_seq_len=max_seq_len
        self.embedding=nn.Embedding(self.vocab_size,d_model)
        self.language_to_index=language_to_index
        self.position_encoder=PositionalEncoding(d_model,max_sequence_length=max_seq_len)
        self.dropout=nn.Dropout(p=0.1)
        self.START_TOKEN=START_TOKEN
        self.END_TOKEN=END_TOKEN
        self.PADDING_TOKEN=PADDING_TOKEN
    
    def batch_tokenize(self,batch,start_token=True,end_token=True):
        def tokenize(sentence,start_token=True,end_token=True):
            sentence_word_indices=[self.language_to_index[token] for token in list(sentence)]
            if start_token:
                sentence_word_indices.insert(0,self.language_to_index[START_TOKEN])
            if end_token:
                sentence_word_indices.append(self.language_to_index[END_TOKEN])
            for _ in range(len(sentence_word_indices),max_seq_len):
                sentence_word_indices.append(self.language_to_index[PADDING_TOKEN])
            return torch.tensor(sentence_word_indices)
        
        tokenized = []
        for sentence_num in range(len(batch)):
           tokenized.append( tokenize(batch[sentence_num], start_token, end_token) )
        tokenized = torch.stack(tokenized)
        return tokenized.to(get_device())
    
    def forward(self, x, end_token=True): # sentence
        x = self.batch_tokenize(x ,end_token)
        x = self.embedding(x)
        pos = self.position_encoder().to(get_device())
        x = self.dropout(x + pos)
        return x

device=get_device()



transformer.to(device)
total_loss = 0
num_epochs = 400


for epoch in range(num_epochs):
    print(f"Epoch {epoch}")
    iterator = iter(train_loader)
    for batch_num, batch in enumerate(iterator):
        transformer.train()
        eng_batch, ta_batch = batch
        encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask = create_masks(eng_batch, ta_batch)
        optim.zero_grad()
        ta_predictions = transformer(eng_batch,
                                     ta_batch,
                                     encoder_self_attention_mask.to(device), 
                                     decoder_self_attention_mask.to(device), 
                                     decoder_cross_attention_mask.to(device),
                                     enc_start_token=False,
                                     enc_end_token=False,
                                     dec_start_token=True,
                                     dec_end_token=True)
        labels = transformer.decoder.sentence_embedding.batch_tokenize(ta_batch, start_token=False, end_token=True)
        loss = criterian(
            ta_predictions.view(-1, ta_vocab_size).to(device),
            labels.view(-1).to(device)
        ).to(device)
        valid_indicies = torch.where(labels.view(-1) == tam_to_ind[PADDING_TOKEN], False, True)
        loss = loss.sum() / valid_indicies.sum()
        loss.backward()
        optim.step()
        #train_losses.append(loss.item())
        if batch_num % 100 == 0:
            print(f"Iteration {batch_num} : {loss.item()}")
            print(f"English: {eng_batch[0]}")
            print(f"Tamil Translation: {ta_batch[0]}")
            ta_sentence_predicted = torch.argmax(ta_predictions[0], axis=1)
            predicted_sentence = ""
            for idx in ta_sentence_predicted:
              if idx == tam_to_ind[END_TOKEN]:
                break
              predicted_sentence += ind_to_tam[idx.item()]
            print(f"Tamil Prediction: {predicted_sentence}")


            transformer.eval()
            ta_sentence = ("",)
            eng_sentence = ("What is your name?",)
            for word_counter in range(max_sequence_length):
                encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask= create_masks(eng_sentence, ta_sentence)
                predictions = transformer(eng_sentence,
                                          ta_sentence,
                                          encoder_self_attention_mask.to(device), 
                                          decoder_self_attention_mask.to(device), 
                                          decoder_cross_attention_mask.to(device),
                                          enc_start_token=False,
                                          enc_end_token=False,
                                          dec_start_token=True,
                                          dec_end_token=False)
                next_token_prob_distribution = predictions[0][word_counter] # not actual probs
                next_token_index = torch.argmax(next_token_prob_distribution).item()
                next_token = ind_to_tam[next_token_index]
                ta_sentence = (ta_sentence[0] + next_token, )
                if next_token == END_TOKEN:
                  break
            
            print(f"Evaluation translation (What is your name?) : {ta_sentence}")
            print("-------------------------------------------")
        
    FILEA="model1save.pth"
    torch.save(transformer,FILEA)

FILEA="finalmodel.pth"
torch.save(transformer,FILEA)


def translate(eng_sentence):
    transformer.eval()
    ta_sentence = ("",)
    eng_sentence=(eng_sentence,)
    for word_counter in range(max_sequence_length):
        encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask= create_masks(eng_sentence, ta_sentence)
        predictions = transformer(eng_sentence,
                                    ta_sentence,
                                    encoder_self_attention_mask.to(device), 
                                    decoder_self_attention_mask.to(device), 
                                    decoder_cross_attention_mask.to(device),
                                    enc_start_token=False,
                                    enc_end_token=False,
                                    dec_start_token=True,
                                    dec_end_token=False)
        next_token_prob_distribution = predictions[0][word_counter] # not actual probs
        next_token_index = torch.argmax(next_token_prob_distribution).item()
        next_token = ind_to_tam[next_token_index]
        ta_sentence = (ta_sentence[0] + next_token, )
        if next_token == END_TOKEN:
            break

    print(f"Evaluation translation (What is your name?) : {ta_sentence}")
    print("-------------------------------------------")

translate('what is your name')
# Out:
# ['ஹ', 'ொ', 'C', '9', 'L', 'ஃ', 'அ', 'ி', 'i', 'ஏ', '7', 'ஓ', '—', '?', 'ன', 'ஞ', 'ா', ':', 'o', 'த', '<END>', '0', "'", 'ெ', 'ர', 'ஸ', '\u2060', 'க', 'ீ', 'ஷ', 'ல', 'ஆ', '-', 'F', 'ே', 'A', 'ட', 'T', 'உ', '்', '6', 'ஊ', '‘', 'ு', '5', '<START>', 'e', 'ந', 'ஜ', '3', '2', 'ண', 'ப', 'a', 'E', 'n', 'l', '4', 'ள', '“', '\u200b', 'm', ',', 'ம', 'ழ', 'ோ', 'N', 'k', '1', 'ங', 't', ')', ' ', '"', 'ை', 'ூ', 'ஒ', 'R', 'g', '”', 'ஈ', '.', 'இ', 'ஐ', 'ய', '`', 'எ', '’', '<PAD>', 's', 'ச', 'u', '(', 'வ', 'ற']
#  ta_vocab = 95 tam_to_ind =95
# [('Some 14 months later, the second calf is born.', '"Senior advocate Kapil Sibal, who was appearing for Chidambaram, said the condition was not justified for a member of Parliament and ""he would not run away anywhere."""', 'This photo was taken then.'), ('சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.', '‘காா்த்தி சிதம்பரம் எம். பி. யாக உள்ளதால் எங்கும் தப்பிவிட மாட்டாா்’ என்று அவரது சாா்பில் ஆஜரான மூத்த வழக்குரைஞா் கபில் சிபல் வாதாடினாா்.', 'அதன்போது எடுக்கப்பட்ட புகைப்படம் இது.')]
# [('So far two rounds of the JWG meeting have been held.', 'The life of the world is nothing but play and diversion, and the abode of the Hereafter is surely better for those who are Godwary. Do you not exercise your reason?', 'The maximum temperature will be 35 degrees Celsius and the minimum will settle at 27 degree.'), ('இதுவரை இணைப் பணிக் குழு இரண்டுகட்ட பேச்சுவார்த்தை முடிவடைந்துள்ளது.', 'உலக வாழ்க்கை வீணும் விளையாட்டுமேயன்றி வேறில்லை பயபக்தியுடையவர்களுக்கு நிச்சயமாக மறுமை வீடே மிகவும் மேலானதாகும். நீங்கள் இதைப் புரிந்து கொள்ள வேண்டாமா?', 'அதிகபட்ச வெப்பநிலை 35 டிகிரி செல்சியஸாகவும் குறைந்தபட்சம் 27 டிகிரி செல்சியஸாகவும் இருக்கும்.')]
# [('If they agreed with a point the speaker made, they hummed or grunted their approval.', 'Farmers in this region largely grow paddy and wheat.', 'With this, a video was released as well.'), ('பேச்சாளர் சொன்ன ஒரு குறிப்போடு அவர்கள் ஒத்திருந்தால், ‘ உம் ’ எனவும் கனத்த உட்குரலிலும் தங்கள் சம்மதத்தைத் தெரிவித்தனர்.', 'இப்பகுதிகளில், நெல், சோளம் போன்ற பயிர்களை விவசாயிகள் சாகுபடி செய்து வருகின்றனர்.', 'இது சம்பந்தமாக ஒரு வீடியோவையும் வெளியிட்டு உள்ளார்.')]
# [('Symptoms of tuberculosis', 'Following decisions were taken in this meeting:', 'For Bhairavar during Ashtami special abhishekams will be done.'), ('மூல நோய்க்கான அறிகுறிகள்', 'இதன் போது நடைபெற்ற குழு கூட்டத்தின் குறித்த விடயம் தொடர்பில் பின்வரும் தீர்மானங்கள் கொண்டுவரப்பட்டது .', 'பைரவருக்கு தேய்பிறை அஷ்டமியில் விசேஷ அபிஷேக ஆராதனைகள் நடைபெறுகின்றன.')]
# [('Its not your fault.', 'As a result of this the election at Jayanagar was postponed', 'What is joy about?'), ('இது உன் பிழையல்ல.', 'இந்த நிலையில், தேர்தல் ஒத்திவைக்கப்பட்ட ஜெயநகர் தொகுதியில் ஜூன் 11-ம் தேதி இடைத் தேர்தல் நடைபெற உள்ளது', 'அப்படி என்ன ஆனந்தம்?')]
# Epoch 0
# Iteration 0 : 5.279481410980225
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: kாஐஸஸஓஐ—தஓஜஓ——kஐkoஓEாாநஓஓ—தநE​நஓஓ-—-———(ெu​இந​aணநநநஇநநநநநஈநநநநநTTTநநkநநநநநநஓk<PAD>நநநநTTநநநநநநநஞஜநநநநநநkTநநந—ந—uஏஞ::kTuஞTTukநTTu:நTஏkநநTTTநTTTTநkந:—நkநநkkkkந-kநநநநkநநந:நTநkநTநநநkநkநநநkkkkநநCஜkC—நநநநkkநநநநநநநநநந‘TTTTTTTTநந-நநTkkநkநuநநTTTநCCCTTTநkஞவஞkk⁠உஞஞஞஞநநநஜந:நந⁠நநநTநTநநநநநநநநநநநநநkநநநநuuநநுCநநCTkTkk:
# Evaluation translation (What is your name?) : ('ாாா்தததததத்்்்்்்ாாாாாாாாாாாாாா்்்்்ா்்்்்ாாாா்்்்்்்்ாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாாததuuuuuாuuuuாாuuuuாாாாாuuuாuாாாததததாாuாuாாாாாாாா\u200b\u200bாாuாuாாாா்்ாாாாா்்்தாாாாா்ாததாாாாாாாாாாாாாாாததததவuuuuuாாாாாuாuuuuuuuாாாாாாாாாாuாாாாாாாாாாாவவவவவuuாkkkவuாாாாா\u200b\u200b\u200b:ாாாவவவவாாாாாாாாாாாாாாாuuuuuuuuuuததத""uuu',)
# -------------------------------------------
# Epoch 1
# Iteration 0 : 3.3163251876831055
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: த்த்்த    ்்்்் ்்்த்்்்த்் ்்த்்்்்்்்ி்த த ் ்்்்்த் ்ி ி்்ா்்்்்ு ்்த்்்்்்்்்்் ்்்்ாி்்்்்் ் ்ததத த்்்்ி் ் ்் ்  ்ி்்த்்்்த்்்த ்த்்்் த ்்்்்ாத்்தத ்்்தத்த்்்் த் ்்்்த்்்் ்்்்்ா்்் ்ததத் தத ் ் ா ்்்்்்்்த் திா்்ாதத்ி்்்்தி்்்ித்்்ாிதத்்தத்தப்்்்்்த்்திி ிிி்ாுி்தா்து்த் ் த ்து ் ்் ு ்த்
# Evaluation translation (What is your name?) : ('்்்்்     ்்்்்்்்்்்்்்்    ்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்் ்்்்்்்்்்்்்்்்்்்்்்்்்ததத்்்்்்்்்்்்்்்்்்்்் ் ்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்ததததத  ்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்த்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்ி<END>',)
# -------------------------------------------
# Epoch 2
# Iteration 0 : 3.296063184738159
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: ்்துத்தத்்து்்் ்்்்்்த்்த ்்்்த்்ி்்்  ்்த்்தி்்்்்த ்்்் ்்்்்்்் ்த்்்்்்்் ்்த்த்்்தத்்்்்ி்  ்த்தி த்்்த்த்் ்்்தத்்்்்்ததத்தத்்்  ்்்்்தத் ்்்்்ிிிி ் ்்்்்ா்்் ்தித்்் ்்தது ் த்ி்்்்தத்தத்த் ் ்்த ் ்்்்த்   ்த்தத்்்்த்்்்்ுதி்்த்ததத்தத்ி ் ி்த்்்்்ி்ித்்்்ிதத்்  ுத்ு்் த த ்த்துு்ுததத்  ் த
# Evaluation translation (What is your name?) : ('தத்்்் ் ்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்தத்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்ததததத்்்்்்்்்்்்்்்்்்்த்்்்்்்்்்்்்்த்்்்்்்்்்்த்்்்்்்்்்்்்்்்்்்்<END>',)
# -------------------------------------------
# Epoch 3
# Iteration 0 : 3.244042158126831
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: தத்ித்ு  ்்்்்்ு்் ்்்்்்ு் ் ் ்த ்்த்்தத்த் ் ்்்்்க ் ்்்்்்்்்்்்து்் ி்்்் ்   த்்்்்  ்்்்்் ்   ்  ்்்ததா்   ்்  ்்்்்்்த்்த்் ்்்்்்்்்்்்ு்்த்்்த   ்  ்்்்ததத த ்்் ்்த்்்்்்்்்்்ி்தத்ததத்   ்்தா்்்்்்்்்்்தததது்த்த்்்த் ித்த்்்்த் ்ததது் ்ிததத்்்்்்்்்ிாத ்  ்ததத்்்்து து்ு்ு்த்்தத்    ் ்
# Evaluation translation (What is your name?) : ('தத்்் ் ் ்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்ததத<END>',)
# -------------------------------------------
# Epoch 4
# Iteration 0 : 3.2712652683258057
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இத்்்  ுத்ு்் த ்்் ் ்்்்  தத்் ்்்்்ததத்த்்் ்த  த் ் ்்் ் ்்்்்்்்்்்் ா்்்த்த்்்்ி்் ்்்்்்் ் ்தத ் ் ்ி்்ர்்்்்த்த்்த  ்த்தத் ்்ு ்்்் ்்்்்்தத்  ்  ் ்்்்்்்்  த  ்்்்்்்்   ்்்்்்்்்த்ததத்த  ்்்  ்் ்்்்்் . தா்த்்்த்்்்்்்்்்்்்தத்தி்்்் த்ுது்்்்்த ்்ிதத த ் ி் த்்ு்ு்் ்ு ்் ுுு்த் ் த த
# Evaluation translation (What is your name?) : ('இத்்்் ் ்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்்<END>',)
# -------------------------------------------
# Epoch 5
# Iteration 0 : 3.201447010040283
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: ததத் ்  ததத்்்்து் ்் ்்லுு்் ்்த்்்்்்்த்்்்்்்த்்்் ்்ி்் ்்்்்த்்ு ்் ்்்்்்த்்்த்்்ுித ்்் ்்்் ் ்  ு்்கதததத்்்்்்் ு்ி ்த்த ்்்்்்்்்்்த்்்்்த்்த்்்ு்  ் த் தத்   த த்்்த் ்்்்்்்்்ாத்த்ததத்தத ் ் ்த்  ்்்்்ி்்த்்்்்்்்ு்்் த ்்்்்்்்்்்ித் ி ்்ி்ா்்்்்்்் ்் ் துா்த்்்்்் ்்ு் த ுுு ்்்த்்்்்
# Evaluation translation (What is your name?) : ('இத்்்் ் ்்்்்்்்்்்்்்்்்்்்்்்்்்்்<END>',)
# -------------------------------------------
# Epoch 6
# Iteration 0 : 3.2551724910736084
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்்்த் ்்்் த்்ு ்்் ்து்்்்்் ்திதத்்த்்த் ்்்்்்்  ச்   ்்் ்்்்்்்்் ி்்்்்்்தததத்.ர ்்்் ்் ்த  ் தத்ு ் த ்  த ் தத ்்்தத்்ததத  ் ்த்்  ்்்்்ததத்்்்  ்்  ்ாத  ்த்   ்்்தத்த்  ்ித் ்் த த்தததத  ்த்்்  ் த்்்்்் தத்்்்த்்த் த்்தத்்்்்த்்்்ு்்  ி ்.்்்்தலத ி ்ததி த ்  த்்்்்த  த்்த்த்ுதத்்்்்
# Evaluation translation (What is your name?) : ('இத்்் ் ் ்்்்்்்்்்்்்்்்்்்்்்்்்்.<END>',)
# -------------------------------------------
# Epoch 7
# Iteration 0 : 3.166102886199951
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்ு்     ்்்் ு்   ்்் ்்்்த்தத்்் த்் ்்் ்்்்்் ்்  ரி ்் ்்்்்்    ்ி்்்்்்ர்த ்ித் ர்்்ி்்்்்்   த  ்த ித த்்தத்ததி  ்்  தததததத்்்்்ததத   ்்்த்்த்்்ின்்   த  ்      ்்்்்  ்    ்்்் ்்ததததத்த      ்்ட    ்்்்்த.த்தத்்்த்்்்த  ்ு்்த்்்்்ததததத ் ்.்்்்தித்்்்் ன  ு த  த்்ு ததத  ் த துு த்த ்
# Evaluation translation (What is your name?) : ('இத்் ் ் ் ்்்்்்்்்்்்்்்்்்.<END>',)
# -------------------------------------------
# Epoch 8
# Iteration 0 : 3.124164342880249
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: ததத்்் தததததத்்த்ை  ்  ் ்்் ்்்த்த் ி்் த்்்்்்த்்த
# Evaluation translation (What is your name?) : ('இத் ் ் த் ் ் ் ் ் ்்்.்.்.<END>',)
# -------------------------------------------
# Epoch 9
# Iteration 0 : 2.992957592010498
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்ு்  ததத்்்் ்்  ்  ் ுததத்்் ் ் த்்த் ள்் ்தி்
# Evaluation translation (What is your name?) : ('இத்        த் த் த்   .<END>',)
# -------------------------------------------
# Epoch 10
# Iteration 0 : 2.8852431774139404
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதது ் த்தத்த்் ிி  ்்த் ்த த ்் ்த் த்்த்   ் ்த்்
# Evaluation translation (What is your name?) : ('அச்   ச் த் த்த் ச் ச் த்த்த்.<END>',)
# -------------------------------------------
# Epoch 11
# Iteration 0 : 2.8881471157073975
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்த்ததததத்த்்த்்தத்் ்துத தத்் ்ய் த்ாத் யள் ்ய்ி
# Evaluation translation (What is your name?) : ('இது த் த் த் த்த்.<END>',)
# -------------------------------------------
# Epoch 12
# Iteration 0 : 2.750145435333252
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: ததத்த ததததத்து்த்ை த்்ய் ் தத ்்த் ் த்்த்த.்் ்யு்
# Evaluation translation (What is your name?) : ('சதாத் த் த் த்த்த் ச் ச்.<END>',)
# -------------------------------------------
# Epoch 13
# Iteration 0 : 2.713240385055542
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்ததததததத்த்்த்் த்்லுத்த தத்்த்த்ததா்த்யதள் ாய்்
# Evaluation translation (What is your name?) : ('சது த் ச் த் த்த் ச் ச்.<END>',)
# -------------------------------------------
# Epoch 14
# Iteration 0 : 2.7096099853515625
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்்்ததததத்்்்த்் ல்்ர் ் ்தத்்த்ட் ப்்திதபள் ்யு்த
# Evaluation translation (What is your name?) : ('சில் த் த் த்த்த்த் ச்.<END>',)
# -------------------------------------------
# Epoch 15
# Iteration 0 : 2.596808671951294
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்த்ததததத்த்் ்்தத்்ரு ு ததது்த்ண் வ்்த்யவள் ாய்ு
# Evaluation translation (What is your name?) : ('சில் ச் த் த்த்தில் ச்.<END>',)
# -------------------------------------------
# Epoch 16
# Iteration 0 : 2.619534969329834
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்்்தத் த்ா்் ்் வாுயுத்  தத்்த்ண் வ்்தாலசர்ப்க்ு.
# Evaluation translation (What is your name?) : ('சில் ச் த் த்த்த்த் ச்.<END>',)
# -------------------------------------------
# Epoch 17
# Iteration 0 : 2.529086112976074
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்த்ததததத்த்் ா் ச்்ர் ு தமன்்த்ர்கபாாதாபப ்பான்்
# Evaluation translation (What is your name?) : ('சில் ச் த் த்த்தில் ச்.<END>',)
# -------------------------------------------
# Epoch 18
# Iteration 0 : 2.4714748859405518
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத்்ுதஇதகத்்்் ா் இு்யு ்த தத்் ்ர் ப்்த் வன்க்க்்.
# Evaluation translation (What is your name?) : ('சில் ம் த் ச்த்த்.<END>',)
# -------------------------------------------
# Epoch 19
# Iteration 0 : 2.4786157608032227
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத் த த  த்த்் ா் த்ாற் ு  தத்் ்ர்கத்்தா பள் ்யிு
# Evaluation translation (What is your name?) : ('இதால் ச் ச் ச்த்த்.<END>',)
# -------------------------------------------
# Epoch 20
# Iteration 0 : 2.3922066688537598
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத் ்தசத த்த்் ்் க்் ு ி  பதா் ்ண் ச்்தி வர் ாத்ு
# Evaluation translation (What is your name?) : ('சில் சிய் ச்த்த்த்.<END>',)
# -------------------------------------------
# Epoch 21
# Iteration 0 : 2.4116361141204834
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத் ் தத ந்ன்் ்் த்்ரு ு  தரு்த்ட் வ்ாதி வ ் ்ய்ு
# Evaluation translation (What is your name?) : ('சில் சிய் ச்த்தில்.<END>',)
# -------------------------------------------
# Epoch 22
# Iteration 0 : 2.3317620754241943
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத் ் தததத் ு் ்ு க்்ரு ுள இர்் ்ர் க்்தி வள்ளிர்ுட
# Evaluation translation (What is your name?) : ('இதால் அத் எழ்த்தில்.<END>',)
# -------------------------------------------
# Epoch 23
# Iteration 0 : 2.3961918354034424
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுு்்ு தததபாணு் ுு ம்்று ு  மன்்ற்ண் வி்தி சன் ்னுு
# Evaluation translation (What is your name?) : ('இதாாும் த் ஆழ்த்து ச்.<END>',)
# -------------------------------------------
# Epoch 24
# Iteration 0 : 2.2209560871124268
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத் ு ததததாாு்க்் க்ு ு ு  கண்் ு்் வ்்தி பன் ிதுு
# Evaluation translation (What is your name?) : ('சில் என் ந் ஆன்தில் ச்.<END>',)
# -------------------------------------------
# Epoch 25
# Iteration 0 : 2.3409605026245117
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத் ுதஇததத்்ு்புு பு்று ு  கத்் ்ிி கி்தி வர் ிபுு
# Evaluation translation (What is your name?) : ('சில் என் ந் ஆன்தில் ச்.<END>',)
# -------------------------------------------
# Epoch 26
# Iteration 0 : 2.194124698638916
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இித்்ுததததப்து் ு் த்்ருது  தர்்திர் த்்திதபன்கியதுட
# Evaluation translation (What is your name?) : ('சிது பின் ந்த்திது ச் சில்த்த்.<END>',)
# -------------------------------------------
# Epoch 27
# Iteration 0 : 2.1772780418395996
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதம் ் தத த்னு் ா் க்ெ ு ு  இரு் ்ண் ப்்தை ஈட் ்றுு
# Evaluation translation (What is your name?) : ('அவாது என் ந்த்தில் செழாாாத்த்து.<END>',)
# -------------------------------------------
# Epoch 28
# Iteration 0 : 2.220820426940918
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத்ர் மண ந்த்் ்் க்் ு ு  மர்் ்ர் பா்டா வன்ன்ன்்
# Evaluation translation (What is your name?) : ('சில் என் எழ்ச்த்து ச்சாாா்த்த்.<END>',)
# -------------------------------------------
# Epoch 29
# Iteration 0 : 2.138756036758423
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத்்்தநததம்ன்்றள்தபள்ருறுமனஇன்் ்ர்தவ்்திதவன்றளயத்
# Evaluation translation (What is your name?) : ('இதாதும் ந்த்த்திய் ச்.<END>',)
# -------------------------------------------
# Epoch 30
# Iteration 0 : 2.023576021194458
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இஙத்ர்தமததத்தா்ப்் குுறுறும கர்்த்ர் க்்த்தபன் ிற்ு
# Evaluation translation (What is your name?) : ('அவர்தும் ந்த்த்திய் சாாாாத்த்த்.<END>',)
# -------------------------------------------
# Epoch 31
# Iteration 0 : 2.020441770553589
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமத் ் நத க் ங்த்் குு ு ும பன்்தி ் க்்த் ஈன் ாற்ு
# Evaluation translation (What is your name?) : ('அவாது ம் ந்த்த்தில் சாாாா்த்த்த்.<END>',)
# -------------------------------------------
# Epoch 32
# Iteration 0 : 1.9583616256713867
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இதத் ்தமணதக்த்்த்்ககள் ுதும கர்்த்்் க்்த் பன்களகது டணணரரரரடடடடடரரரரகன ரரடடடடடரரடடதததததடடடடதததகறடடதததடததததரததடடடடததததறதரரதததகககததததடடதததட தனதத தடடடடaணணணணணடடடனத ததனறனறற  :ற  -4 டடடத ததததததரரரததததத6ரரரரடரடடடரடடரடகககடடடடதரரரகணரடடடடடடடடடடரரதளரகரரதணததததததளளளரதரரரரரரரரரரரரர ரரடரதரரதடடதரதரரடடதததததததததரரரரத
# Evaluation translation (What is your name?) : ('அத்தும் ந்த்த்த்த்த் ச்க்த்த்த்.<END>',)
# -------------------------------------------
# Epoch 33
# Iteration 0 : 1.98702073097229
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இஙத் ்தகததக்னங் ு் குுரு ும கர்் ்ர்டக்்தி ஈன் ிற்ுட
# Evaluation translation (What is your name?) : ('சிப்தும் ந்த்ச்த்த் சாாாாத்த்த்.<END>',)
# -------------------------------------------
# Epoch 34
# Iteration 0 : 1.9578560590744019
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இஙம்த்ததததந்ங்் ்் க்ுரு ு  தர்்த்த் க்்த் கன்கிற்ுத
# Evaluation translation (What is your name?) : ('சித்தும் ந்த்த்தான் சாாா்த்த்த்.<END>',)
# -------------------------------------------
# Epoch 35
# Iteration 0 : 1.9267498254776
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: தமத்ர்ததனதமானங்து்கமுழருறும கரம்ற்ண் கி்திதஈன்றதறுு டணசரசரரடடடடயரரரரததரரடடரடடததரதரததததடடடடடததரரமடடததததனடதடதரதரடடடடடததறதரசததததததயதததடடடதத4 னனததணணமணடடரணணணணணeனFaதத ததததறத4த44ய4444ட44 ததததரணதததணதததததரரரடரடரடடரகடடயரகககரடடததணரரத ணரரரண-டதரடரரரரரததரதததததததததளளளரரரறரரரரரரரரரரரரரரடாதரரதததததரரரததததததததததததரரரத
# Evaluation translation (What is your name?) : ('அவருதும் நிழ்த்துதும் காாத்த்தார்.<END>',)
# -------------------------------------------
# Epoch 36
# Iteration 0 : 1.881907343864441
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இஙத் ்தபததமான்் ்் குழழு ு  கர்் ்ண் க்்த் பன்றிறிு
# Evaluation translation (What is your name?) : ('சிதுது பிழிழ்த்தில் செய்யியித்.<END>',)
# -------------------------------------------
# Epoch 37
# Iteration 0 : 1.8100529909133911
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ர்தகத நாகா் ள்ககுு ு ு  கரத்ப்ர் க்்தத வன் ிபத் டணசரரரரடடசடயரரரர ரத ரடரடரதயரததததததடடடடரரரரததகதளததததனடததரததரடடணதததறதசசதததததததததகததத    ற தத  ண கக  ணணணணடனனத a த  ர      றற  44ட   ரததததரரர 6ததததரரரரரரரகரகககயயகககடடயடதரரரதர  ரர த தடடரரரரததரரதததததததத  ரததரரரரரரரரரரரரரதரரரதததரரதரடதரரததததததததததததததரர ர
# Evaluation translation (What is your name?) : ('சில்தி பில்த்சியில்ச்சாா்தித்த்.<END>',)
# -------------------------------------------
# Epoch 38
# Iteration 0 : 1.7888696193695068
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ரை ம4 தாதங்றள் கழழ ுது  க ்் ்ரி கி்தத ஈ ்றிறுு  ண சரரர டட ரயரரரரர னடடடடடரரரதரதததரடடடடடதரரரடடடதததடதடரததரடதடடணடதததரரசகதததததயககதததததத த னதத ்ண டயா ணணணடடட கஸm   தரரரற   யறய   4ர   தததரரதரர :தததரரரரரரரடரரடககயரககரகடடடடடர ரர ர ர வததடடடரடரதரரததரதத தததததளளளரதரரரரரரரரரரரரர  தடரரரரரரரததரரதடததததததததடததரர ர
# Evaluation translation (What is your name?) : ('அவர் எர் எழ்த்சில்ல் சாா்ம்த்.<END>',)
# -------------------------------------------
# Epoch 39
# Iteration 0 : 1.8179506063461304
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: மமம் ் மத காதா் ற் க ் ு ு  கர்் ்ன் க்்த் ஈன் ாற்ு
# Evaluation translation (What is your name?) : ('அவர் எரிய் ஆத்தியா?<END>',)
# -------------------------------------------
# Epoch 40
# Iteration 0 : 1.7910257577896118
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத்ர் மதததானங்றள் குுழு ு  தரு்ற்ன் கி்தி ஈனு ளறுு
# Evaluation translation (What is your name?) : ('சாது எரிக் ஆத்தில் சாழ்.<END>',)
# -------------------------------------------
# Epoch 41
# Iteration 0 : 1.7264256477355957
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமம் ு க4 மானங்கள்ககுுழு ு  கன்்த்ன் கி்தைலவட் ொறத்
# Evaluation translation (What is your name?) : ('அவரு எனர் என்சனனான் சாகள்ம்.<END>',)
# -------------------------------------------
# Epoch 42
# Iteration 0 : 1.679334044456482
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்த்தபத ந்னா்ற்்ககுுழு ும ஈர்் ்னாதஈ்்தததஈன் ிறது.
# Evaluation translation (What is your name?) : ('அவரு எருக்த்த்தன்து சாகும்ததது.<END>',)
# -------------------------------------------
# Epoch 43
# Iteration 0 : 1.520145297050476
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இஙக் ் இ4தநாதங்கள் குழழுது  இர்் ்மா க்்தை வன்கமதது
# Evaluation translation (What is your name?) : ('அவரு எனிக் ஆத்தில் சாழ்றும்த்தார்.<END>',)
# -------------------------------------------
# Epoch 44
# Iteration 0 : 1.528698205947876
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமதை ு 14 நாது் ்்ககுழழுதும சர்்தமண் கி்தை ஈன்கிறுு.
# Evaluation translation (What is your name?) : ('அவரு எருக் ஆத்தில்?<END>',)
# -------------------------------------------
# Epoch 45
# Iteration 0 : 1.5086473226547241
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ்தம4 மாங்்கள்ககுு ் ்ம கணண் ்ண் க்்த் வன்கிதத்
# Evaluation translation (What is your name?) : ('சிது எரிக் ஆத்தில் செய்.<END>',)
# -------------------------------------------
# Epoch 46
# Iteration 0 : 1.4884411096572876
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ரிதப4 நாதங்த ் கழி ுதும கணி் ்ரி கி்தை ஈனி ிறது
# Evaluation translation (What is your name?) : ('அவரும் என் ஆத்திலா?<END>',)
# -------------------------------------------
# Epoch 47
# Iteration 0 : 1.472254991531372
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ் சண நோதெ்கள் கழழ ுது, கண்் ிம் கு்ற் ஈ ்கிறமு.
# Evaluation translation (What is your name?) : ('சிபடு எனிழிழ்தியில் செய்.<END>',)
# -------------------------------------------
# Epoch 48
# Iteration 0 : 1.4857732057571411
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்த் 14 மோதங்க்்,குுழுதும கரி்றமன் பன்றைதபன்றிறதொப
# Evaluation translation (What is your name?) : ('ஏகாடு எனிழிழ்தனில்?<END>',)
# -------------------------------------------
# Epoch 49
# Iteration 0 : 1.3604506254196167
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத்ர்த14 நடது்கள்ககுி ுது, இர்்ன்ன் க்்தைதவன் ிறுு.
# Evaluation translation (What is your name?) : ('ஏவரு எனருக்தத்தனா?<END>',)
# -------------------------------------------
# Epoch 50
# Iteration 0 : 1.382818579673767
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ர் ம4 மானா் ள் கழிழு ு  கர்் ்ம் பி்றி பனி ியமு
# Evaluation translation (What is your name?) : ('சண்படிருக்ன்ச்சில் செய்யுமததத்.<END>',)
# -------------------------------------------
# Epoch 51
# Iteration 0 : 1.3272500038146973
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ் ம4 மோது்கள  குுகுதும கர்் மம் க்்த் ஈன்மதகமு
# Evaluation translation (What is your name?) : ('அபடு எருக் ஆதியில் வாழ்கும்ததார்.<END>',)
# -------------------------------------------
# Epoch 52
# Iteration 0 : 1.3082129955291748
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ் ப4 பாதங்கள் குு ுது  இரண்தாரா கு்தை பன  தறது
# Evaluation translation (What is your name?) : ('அவரு எரிக என்தனையோ?<END>',)
# -------------------------------------------
# Epoch 53
# Iteration 0 : 1.3146770000457764
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ் 1த சோது்றள் கழழழுது, கத்்ததம் கி்றை வனிறிறுும
# Evaluation translation (What is your name?) : ('அவருமிரதுக்தததினம்?<END>',)
# -------------------------------------------
# Epoch 54
# Iteration 0 : 1.2116509675979614
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார் ம4 மாடங் ள் குழழ் ும கரண்ட்ரா என்தை ஈன் ிறுு.
# Evaluation translation (What is your name?) : ('சண்படி என்ன ஆதனில் செய்குமததததார்.<END>',)
# -------------------------------------------
# Epoch 55
# Iteration 0 : 1.197993278503418
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமம் ்தம4 மாதங்கள் களுழு ு, மர்்மமம் கன்த் ஈனிமியமு
# Evaluation translation (What is your name?) : ('அவருது மிழ்த்தனை?<END>',)
# -------------------------------------------
# Epoch 56
# Iteration 0 : 1.2607961893081665
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இெ ார் ந4 நாடா்க ் கழழழ்த , இரண் ான் கா்தா ஈன் ொயதுட
# Evaluation translation (What is your name?) : ('சண்டு என்ன ஆத்தன்து சாக்றித்தார்.<END>',)
# -------------------------------------------
# Epoch 57
# Iteration 0 : 1.18264639377594
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமம்ர் 14 மாதங்கள் குுழு ு, இர்்ற்ம் கி்த் ஈன் ிறுு.
# Evaluation translation (What is your name?) : ('அவரும் மிழ்ச்சியில் சழ்யும்த்தார்.<END>',)
# -------------------------------------------
# Epoch 58
# Iteration 0 : 1.2309274673461914
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமா ் ம4 நாதங்க்்ககுுத்த்ம மரம் ்ம் க்்தைதவன்கிகம்
# Evaluation translation (What is your name?) : ('அவரு எர் என்ச்சிய் சாழ்கும்த்தார்.<END>',)
# -------------------------------------------
# Epoch 59
# Iteration 0 : 1.1359896659851074
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுத்ர் 11 ந்தங் ள் குுது ும இண்்த்ம் கன்தை தன  ிதமு.
# Evaluation translation (What is your name?) : ('அவரும் ம் ந்ச்தன் ந்ச்க்ம்த்த்.<END>',)
# -------------------------------------------
# Epoch 60
# Iteration 0 : 0.9896224141120911
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ் 14ணமாத்்கள் கழு ்து, இர்்த்ம் கன்றை ஈனிகிறுொ.
# Evaluation translation (What is your name?) : ('அவரு என் என்ச்சன் ந்ச்க்ம்த்த்.<END>',)
# -------------------------------------------
# Epoch 61
# Iteration 0 : 1.0457162857055664
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமமார்தம4 மாடங்றள்ககழழருதும இணண்ட்மா கட்த தஈனிகிறொுட
# Evaluation translation (What is your name?) : ('அவரும் மான் ஆனந்தம் வாக்மதத்தார்.<END>',)
# -------------------------------------------
# Epoch 62
# Iteration 0 : 1.0865917205810547
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இஙமார் 1ண நாஙங்றற் கழிழிது, இர்்றணம் கன்றத ஈனிறிறதுத
# Evaluation translation (What is your name?) : ('அவர் எரதிழ்த்சநியம் சாய்மதித்தார்.<END>',)
# -------------------------------------------
# Epoch 63
# Iteration 0 : 0.983851432800293
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார்தச44நடதங்கள் கழுழுது, இர்்தமம் வன்றைவவனுகிறது.
# Evaluation translation (What is your name?) : ('அவரும் என்ன்சியில்?<END>',)
# -------------------------------------------
# Epoch 64
# Iteration 0 : 0.9229433536529541
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார் 144மாதா்றள்ககழழத்து, கர்்தாமா கனாதைதஈன்கிறமு.
# Evaluation translation (What is your name?) : ('அப்படி மகிழ்த்தியோடு சம்மதோம்தார்.<END>',)
# -------------------------------------------
# Epoch 65
# Iteration 0 : 0.9004167914390564
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ர் 14 மாதங்றள் குி ு ு, இணண் ்ம் கன்றை வனிமிறமு.
# Evaluation translation (What is your name?) : ('அவரும் மகிழ்ச்தில் வாழம்மதத்தம்.<END>',)
# -------------------------------------------
# Epoch 66
# Iteration 0 : 0.9161303639411926
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ரு 14 மடடங் ள் கழு ு ு, மர்்தமம் ஈன்றை ஈனு ிடமு.
# Evaluation translation (What is your name?) : ('அவரும் மக என்தன்தம் வழம்மததத்தார்.<END>',)
# -------------------------------------------
# Epoch 67
# Iteration 0 : 0.8791458606719971
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும் ் 14 மாதங்கள் குு ்து, இண்்பாம் கன்தத ஈனுறளறத்
# Evaluation translation (What is your name?) : ('அப்படும் என்த்தன.<END>',)
# -------------------------------------------
# Epoch 68
# Iteration 0 : 0.9105175137519836
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார்த14 மாதங்கள்றகழழதுது, 1ணண்த்மா கு்றை ஈனிறிறமு.
# Evaluation translation (What is your name?) : ('அப்படி மக்ன்த்தியம் வழ்ம்மததம்.<END>',)
# -------------------------------------------
# Epoch 69
# Iteration 0 : 0.8397636413574219
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுாார் 14 சாதங்கள்ககழிழ்து, இண்்ட்ம் கா்த் ஈன்கிறமு.
# Evaluation translation (What is your name?) : ('அவ்படி மதிழ்ச்தியம் சாம்மதத்த்.<END>',)
# -------------------------------------------
# Epoch 70
# Iteration 0 : 0.7930486798286438
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் ச4 நாதங்  ் குுதுது  இர்்டாம் கன்தை ஈலு ிறுும
# Evaluation translation (What is your name?) : ('அவரும் ம்ன்த்த்தம்?<END>',)
# -------------------------------------------
# Epoch 71
# Iteration 0 : 0.7308085560798645
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சும ர் 14 மிதங்கள் கழுதுது  கணண்தைம் கன்றை ஈன்கிகது.
# Evaluation translation (What is your name?) : ('அவம் மாமக் ஆத்தனம் வாழம்மததத்தார்.<END>',)
# -------------------------------------------
# Epoch 72
# Iteration 0 : 0.717860996723175
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமா ர 14 நாதங்கள்றகழிழாது, இரண்டணம் கனாறைலஈனுகொறமு.
# Evaluation translation (What is your name?) : ('அபடும் மகிழ்த்தில் வாழம்மதத்தம்.<END>',)
# -------------------------------------------
# Epoch 73
# Iteration 0 : 0.7275158762931824
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமரர் 1ண முதங்கள் கழிதுது, இரண்டமம் கனனறை ஈனுறிறது.
# Evaluation translation (What is your name?) : ('அவரும் மகிழ்த்தானம்?<END>',)
# -------------------------------------------
# Epoch 74
# Iteration 0 : 0.6498478651046753
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 144மானங்கள்ககழுடுது, இரணணடாம் கன்தை ஈனுகிறுு.
# Evaluation translation (What is your name?) : ('அவரும் என்ன ஆனந்தம்?<END>',)
# -------------------------------------------
# Epoch 75
# Iteration 0 : 0.6682556867599487
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 1  மாதங்கள் கு் ்து, இர்்பாம் கன்றை ஈன்கிக்ுப
# Evaluation translation (What is your name?) : ('அப்படி மக்ன ஆனந்தம் வழம்மதம்தம்.<END>',)
# -------------------------------------------
# Epoch 76
# Iteration 0 : 0.6421740055084229
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ர் 14 பாதங் ள் கழி ் ு  இரண்   ் கன்றை ஈனு ிறுு.
# Evaluation translation (What is your name?) : ('அப்படி மகிழ்த்தன்து வழ்கும்தம்.<END>',)
# -------------------------------------------
# Epoch 77
# Iteration 0 : 0.6215324401855469
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்க்் கழுத்து, இண்்ட்ம் கன்றத ஈட்கிகமு.
# Evaluation translation (What is your name?) : ('அப்படி மக்ன ஆனந்தம் வழ்ம்ம்தம்.<END>',)
# -------------------------------------------
# Epoch 78
# Iteration 0 : 0.5537506937980652
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 நாதங்கள்ககழழற்து, இரண்டாம் கன்ற் ஈனுகிக்ொ.
# Evaluation translation (What is your name?) : ('அப்படி என்ன்ச்தன்து ச்கம்றத்த்.<END>',)
# -------------------------------------------
# Epoch 79
# Iteration 0 : 0.5339378118515015
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார் 14 நாதங்கள் கழிர் ு, இர்்டார் கன்றை ஈனுகிற்ு.
# Evaluation translation (What is your name?) : ('அப்படி மக்ன்ல்ல்தம்?<END>',)
# -------------------------------------------
# Epoch 80
# Iteration 0 : 0.5510104894638062
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்த் 14 பாதங்கள் கழித்து, இரண்னிம் கன்தத வனுகிறுு.
# Evaluation translation (What is your name?) : ('அப்படி என்ன்ல்லில் வழழ்கிறத்தள்.<END>',)
# -------------------------------------------
# Epoch 81
# Iteration 0 : 0.6583573818206787
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமை ை 14 மாதங்களை கழித்து, இணணணடிமா கனனறை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அவபடும் எனிழ்லிலை வாழ்குமதித்.<END>',)
# -------------------------------------------
# Epoch 82
# Iteration 0 : 0.5700848698616028
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இமமார் 14 மடதங்கள்றகழழத்து, இரண்டாம் கனதறதறஈனுகிறது.
# Evaluation translation (What is your name?) : ('அபடும் பணிழில்லில்?<END>',)
# -------------------------------------------
# Epoch 83
# Iteration 0 : 0.5213644504547119
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்றள் குித்து, இரண்தாம் கன்றைதவன்கியத்.
# Evaluation translation (What is your name?) : ('அப்படி மகிழ்ல்லில்)<END>',)
# -------------------------------------------
# Epoch 84
# Iteration 0 : 0.5195335149765015
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ர் 14 மாதங்கள் கழித்து, இர்்ட்ம் கன்ற் ஈன்றிற்ுட
# Evaluation translation (What is your name?) : ('அப்படி மகிழ்ல்தில்)<END>',)
# -------------------------------------------
# Epoch 85
# Iteration 0 : 0.6011074781417847
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாத்்கள் கழழத்து, இர்் ாம் கன்றை ஈன்கிறுு
# Evaluation translation (What is your name?) : ('அப்படி மக் ஆன்ல்தம் வழ்கம்ம்.<END>',)
# -------------------------------------------
# Epoch 86
# Iteration 0 : 0.5258941650390625
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுதார் 14 மாதங்கள் கழிதுது, இர்்டணம் கன்றைதஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி என்ன ஆனநில்?<END>',)
# -------------------------------------------
# Epoch 87
# Iteration 0 : 0.5157226324081421
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழிது,ு, ணரணணடாமா கன்றை ஈனுறிறது.
# Evaluation translation (What is your name?) : ('அப்படி மிழிழியநில் வழழம்மதிதம்.<END>',)
# -------------------------------------------
# Epoch 88
# Iteration 0 : 0.41077661514282227
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து  இர்்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி என்ன ஆனந்தம் வழ்கிறித்தார்.<END>',)
# -------------------------------------------
# Epoch 89
# Iteration 0 : 0.44672197103500366
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்றள்,கழழல்து, இரண்டாம் கன்றை ஈனுறயறதும
# Evaluation translation (What is your name?) : ('அப்படி மில்லியந்ல் வாழ்யிறித்.<END>',)
# -------------------------------------------
# Epoch 90
# Iteration 0 : 0.3677198886871338
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 1  மாதங்கள் கழிதுது, இரண் ாம் கன்றை ஈனுகிக்ு.
# Evaluation translation (What is your name?) : ('அப்படி என்ன ஆனந்தம்?<END>',)
# -------------------------------------------
# Epoch 91
# Iteration 0 : 0.35764676332473755
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 நாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மில்லினநில் நாழியதிம்தார்.<END>',)
# -------------------------------------------
# Epoch 92
# Iteration 0 : 0.36249375343322754
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சும்ர் 14 நாதங்கள் குுத்து, இரண்டாம் கு்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மன்ன ஆனந்தம் சழ்யும்.<END>',)
# -------------------------------------------
# Epoch 93
# Iteration 0 : 0.36293458938598633
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார் 14 மாதங்கள் கழித்து, இரண்தாம் கன்தத ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி இந்ன ஆனந்தம் சழ்யதிற்தார்.<END>',)
# -------------------------------------------
# Epoch 94
# Iteration 0 : 0.3271748125553131
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இர்்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி இரிழ்ல்லில் வழழ்யும்.<END>',)
# -------------------------------------------
# Epoch 95
# Iteration 0 : 0.30071821808815
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழி ்து  இரண்டாம் கன்றை வனுகிறது.
# Evaluation translation (What is your name?) : ('அபடும் என்ன ஆனநில்)<END>',)
# -------------------------------------------
# Epoch 96
# Iteration 0 : 0.3338751196861267
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமரர் 14 மாதங்கள் கழழத்துத இரண்தாம் கன்தைததனுகிதது.
# Evaluation translation (What is your name?) : ('அப்படி மன் ஆனநந்தம் வழ்யதிறம்.<END>',)
# -------------------------------------------
# Epoch 97
# Iteration 0 : 0.3937797248363495
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார் 14 மானங்கள் குு ்,ு, இண்்டாம் கன்றை வனுகிறுு.
# Evaluation translation (What is your name?) : ('அப்படி மன்ன ஆனந்தம் வழ்ம்ம்.<END>',)
# -------------------------------------------
# Epoch 98
# Iteration 0 : 0.3108149468898773
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சும்ர் 14 மாத்்கள் கழித்து, இணண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அவரும் மன்ன ஆனந்தம் வழம்மதோம்.<END>',)
# -------------------------------------------
# Epoch 99
# Iteration 0 : 0.30111628770828247
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: முமார் 14 மாதங்கள் குித்து, இரண்டாம் கன்றை ஈன்கிறது.
# Evaluation translation (What is your name?) : ('அவரும் மகிழ்ல்லில் வழ்யம்ம்.<END>',)
# -------------------------------------------
# Epoch 100
# Iteration 0 : 0.309490829706192
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுதார் 14 மாதங்றள் கழுத்து, இர்்டாம் கன்றை ஈடுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி ம்ன ஆனந்ல் ந்ல்யம்ம்.<END>',)
# -------------------------------------------
# Epoch 101
# Iteration 0 : 0.2455936223268509
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 நாதங்கள் கழழத்து, இர்்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி என்ன ஆனந்தம் வழ்கிறோம்.<END>',)
# -------------------------------------------
# Epoch 102
# Iteration 0 : 0.23229791224002838
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இுமார்த14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி என் நடநந்தம் சழ்யும்.<END>',)
# -------------------------------------------
# Epoch 103
# Iteration 0 : 0.2779407203197479
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமா ் 14 மாகங்கள் கழிது ு, இரண்டாம் கன்றை ஈனுகிற்ு.
# Evaluation translation (What is your name?) : ('அபடு பான என்ல்ல்தம் சழ்யும்.<END>',)
# -------------------------------------------
# Epoch 104
# Iteration 0 : 0.22907477617263794
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி ம்ன ஆன்சன்து)<END>',)
# -------------------------------------------
# Epoch 105
# Iteration 0 : 0.23188509047031403
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றைலஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி என்ன ஆனந்தம்) சம்ம்ம்.<END>',)
# -------------------------------------------
# Epoch 106
# Iteration 0 : 0.2251911759376526
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்றள் கழித்து, இரண்டாம் கன்றை ஈனுகிறைு.
# Evaluation translation (What is your name?) : ('அப்படி என் ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 107
# Iteration 0 : 0.25236448645591736
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: இும்ர் 14 மடதங்கள் கிித்து, இரண்டாம் கன்றை ஈிுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி பக்ன ஆனந்தம் சாக்கத்கள்.<END>',)
# -------------------------------------------
# Epoch 108
# Iteration 0 : 0.18822002410888672
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழுத்து, இரண்ட்ம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி பில்ல்ல்ல்)<END>',)
# -------------------------------------------
# Epoch 109
# Iteration 0 : 0.2001173198223114
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாமா கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி பில்ல்லில்)<END>',)
# -------------------------------------------
# Epoch 110
# Iteration 0 : 0.20489270985126495
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழிதுது, இரண்தாம் கன்தைதஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி இண்ன ஆனநில்)<END>',)
# -------------------------------------------
# Epoch 111
# Iteration 0 : 0.21475915610790253
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாத்்கள் கிித் ு, இர்்டாம் கன்றை ஈன்டிறது.
# Evaluation translation (What is your name?) : ('அப்படி மிழ் ஆனந்தம்?<END>',)
# -------------------------------------------
# Epoch 112
# ...
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ர்படி மில் ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 357
# Iteration 0 : 0.004097260069102049
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ர்படி மில் ஆனந்தம்?<END>',)
# -------------------------------------------
# Epoch 358
# Iteration 0 : 0.004033670295029879
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி மில்ல ஆன்தம்ல் கில்ம்.<END>',)
# -------------------------------------------
# Epoch 359
# Iteration 0 : 0.012617404572665691
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இத்படி மிழ்லையனில்)<END>',)
# -------------------------------------------
# Epoch 360
# Iteration 0 : 0.03862868621945381
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இதும் இரதிழ்லியில்)<END>',)
# -------------------------------------------
# Epoch 361
# Iteration 0 : 0.06564177572727203
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இதம்போ மில்கனந்தம்)<END>',)
# -------------------------------------------
# Epoch 362
# Iteration 0 : 0.054187286645174026
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இது படிய்னிலையந்தம் வழ்யம்ம்.<END>',)
# -------------------------------------------
# Epoch 363
# Iteration 0 : 0.12753555178642273
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழுத்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அபரது இரதிழ்லந்தம்)<END>',)
# -------------------------------------------
# Epoch 364
# Iteration 0 : 0.048640280961990356
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி ம்றிழ்சனில்)<END>',)
# -------------------------------------------
# Epoch 365
# Iteration 0 : 0.03418397530913353
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 366
# Iteration 0 : 0.03971082344651222
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அபரும் மில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 367
# Iteration 0 : 0.00784725695848465
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அபரும் மில் ஆனநில்)<END>',)
# -------------------------------------------
# Epoch 368
# Iteration 0 : 0.012100160121917725
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மிழ்கழநியம்)<END>',)
# -------------------------------------------
# Epoch 369
# Iteration 0 : 0.007103829178959131
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மில் ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 370
# Iteration 0 : 0.002616920741274953
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி இருக்லியில்)<END>',)
# -------------------------------------------
# Epoch 371
# Iteration 0 : 0.010403270833194256
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி பில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 372
# Iteration 0 : 0.04463505744934082
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 373
# Iteration 0 : 0.009841272607445717
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மிழ்லியனில்)<END>',)
# -------------------------------------------
# Epoch 374
# Iteration 0 : 0.008746507577598095
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி என்ல்லநந்தம்)<END>',)
# -------------------------------------------
# Epoch 375
# Iteration 0 : 0.016087951138615608
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி மில்லியந்தம்)<END>',)
# -------------------------------------------
# Epoch 376
# Iteration 0 : 0.003113094950094819
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ர்படி என்ல் ஆனில்)<END>',)
# -------------------------------------------
# Epoch 377
# Iteration 0 : 0.010085416957736015
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி இர்லினந்லை.<END>',)
# -------------------------------------------
# Epoch 378
# Iteration 0 : 0.004791391547769308
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி பில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 379
# Iteration 0 : 0.003987458534538746
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி என்லியனநில்)<END>',)
# -------------------------------------------
# Epoch 380
# Iteration 0 : 0.013005168177187443
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி மில் ஆனநில்)<END>',)
# -------------------------------------------
# Epoch 381
# Iteration 0 : 0.01563580520451069
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றி ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி இன்ல ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 382
# Iteration 0 : 0.003954512998461723
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ரு பான் பிழஆனந்ல.<END>',)
# -------------------------------------------
# Epoch 383
# Iteration 0 : 0.02742408774793148
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் காித்து, இரண்டாம் கனைறை ஈனுகிறுு.
# Evaluation translation (What is your name?) : ('இப்படி இழில்லியன்)<END>',)
# -------------------------------------------
# Epoch 384
# Iteration 0 : 0.01112914364784956
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி இழிழிழனந்தம்)<END>',)
# -------------------------------------------
# Epoch 385
# Iteration 0 : 0.03998066112399101
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சும்ர் 14 காதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி மிழிழனந்ம.<END>',)
# -------------------------------------------
# Epoch 386
# Iteration 0 : 0.012883798219263554
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ப்படி என் ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 387
# Iteration 0 : 0.006387036293745041
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி மில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 388
# Iteration 0 : 0.008349794894456863
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('இப்படி ம்ன்லியன்தம்)<END>',)
# -------------------------------------------
# Epoch 389
# Iteration 0 : 0.005498169921338558
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ப்படி மில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 390
# Iteration 0 : 0.013813325203955173
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ரு படிய பிழ்டனில்)<END>',)
# -------------------------------------------
# Epoch 391
# Iteration 0 : 0.01929548755288124
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மிழ ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 392
# Iteration 0 : 0.030039861798286438
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள்றகழித்து, இரண்றாம் கன்றை ஈனுகிறது
# Evaluation translation (What is your name?) : ('(ர்படி மிழ ஆனனந்தம்)<END>',)
# -------------------------------------------
# Epoch 393
# Iteration 0 : 0.008985049091279507
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மில் ஆனந்தம் வழியம்ம்.<END>',)
# -------------------------------------------
# Epoch 394
# Iteration 0 : 0.01811356097459793
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழி ்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி மிழ்னியனில்)<END>',)
# -------------------------------------------
# Epoch 395
# Iteration 0 : 0.015139808878302574
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('அப்படி என்ன ஆனந்தம்?<END>',)
# -------------------------------------------
# Epoch 396
# Iteration 0 : 0.01791534759104252
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ர்படி ம்ன ஆனந்தம்)<END>',)
# -------------------------------------------
# Epoch 397
# Iteration 0 : 0.0060131908394396305
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ர்படி மில்லியனில்)<END>',)
# -------------------------------------------
# Epoch 398
# Iteration 0 : 0.01431504637002945
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிடது.
# Evaluation translation (What is your name?) : ('(ர்படி மில் ஆனந்தம் வழியம்ம்.<END>',)
# -------------------------------------------
# Epoch 399
# Iteration 0 : 0.0170582365244627
# English: Some 14 months later, the second calf is born.
# Tamil Translation: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Tamil Prediction: சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.
# Evaluation translation (What is your name?) : ('(ர்படி மில்லியன்தம்)<END>',)
# -------------------------------------------
# Evaluation translation (What is your name?) : ('(ரும் பில்ல் ஆனில்)<END>',)
# -------------------------------------------

# %%
def translate(eng_sentence):
    transformer.eval()
    ta_sentence = ("",)
    eng_sentence=(eng_sentence,)
    for word_counter in range(max_sequence_length):
        encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask= create_masks(eng_sentence, ta_sentence)
        predictions = transformer(eng_sentence,
                                    ta_sentence,
                                    encoder_self_attention_mask.to(device), 
                                    decoder_self_attention_mask.to(device), 
                                    decoder_cross_attention_mask.to(device),
                                    enc_start_token=False,
                                    enc_end_token=False,
                                    dec_start_token=True,
                                    dec_end_token=False)
        next_token_prob_distribution = predictions[0][word_counter] # not actual probs
        next_token_index = torch.argmax(next_token_prob_distribution).item()
        next_token = ind_to_tam[next_token_index]
        ta_sentence = (ta_sentence[0] + next_token, )
        if next_token == END_TOKEN:
            break

    print(f"Evaluation translation ({eng_sentence}) : {ta_sentence}")
    print("-------------------------------------------")

translate('where are you?')
translate('Thanks')
# Out:
# Evaluation translation (('where are you?',)) : ('ஸ்மோக்பிக் கொண்கான்ட கோாா - 100 கிராம்<END>',)
# -------------------------------------------
# Evaluation translation (('Thanks',)) : ('திலே உயிக்கொய்டேலே<END>',)
# -------------------------------------------

# %%
translate('Some 14 months later, the second calf is born.')
# Out:
# Evaluation translation (('Some 14 months later, the second calf is born.',)) : ('சுமார் 14 மாதங்கள் கழித்து, இரண்டாம் கன்றை ஈனுகிறது.<END>',)
# -------------------------------------------

# %%
translate('What is joy about?')
# Out:
# Evaluation translation (('What is joy about?',)) : ('அப்படி என்ன ஆனந்தம்?<END>',)
# -------------------------------------------

# %%
translate('I don\'t know')
# Out:
# Evaluation translation (("I don't know",)) : ('எனக்கு தெரியவில்லை<END>',)
# -------------------------------------------

# %%
translate('Thank you')
# Out:
# Evaluation translation (('Thank you',)) : ('நன்றி நன்றி நன்றி<END>',)
# -------------------------------------------

# %% [markdown]
# translate(')

# %%
translate('Some 14 months later, the second calf is born.')
# Out:
# Evaluation translation (('Some 14 months later, the second calf is born.',)) : ('இதன் பித்த் தங் க் க கு கள்த் ப் பட் க்த்த் ஈடியியொட்ட்ட்.<END>',)
# -------------------------------------------

# %%
def save_checkpoint(state,filename="savetest.pth.tar"):
    torch.save(state,filename)

checkpoint={'state_dict' : transformer.state_dict(), 'optimizer' : optim.state_dict()}
save_checkpoint(checkpoint)

# %%
translate('what is joy about?')
# Out:
# Evaluation translation (('what is joy about?',)) : ('என்ன பயன் என்ன?<END>',)
# -------------------------------------------

# %%
translate('Happy birthday')
# Out:
# Evaluation translation (('Happy birthday',)) : ('குழந்தை மகிழ்ச்சி<END>',)
# -------------------------------------------

# %%
translate('What is your name?')
# Out:
# Evaluation translation (('What is your name?',)) : ('உங்கள் என்ன பெயர்?<END>',)
# -------------------------------------------

# %%
translate('Why are you sad')
# Out:
# Evaluation translation (('Why are you sad',)) : ('ஏன் என்னை ஏன் இப்படி இருக்கிறீர்கள்?<END>',)
# -------------------------------------------

# %%
translate('Leave me alone')
# Out:
# Evaluation translation (('Leave me alone',)) : ('என்னை விட்டு விட்டு விடுவோம்<END>',)
# -------------------------------------------

# %%
translate('That was good!')
# Out:
# Evaluation translation (('That was good!',)) : ('அது நல்லாம்!<END>',)
# -------------------------------------------

# %%
translate('How are you?')
# Out:
# Evaluation translation (('How are you?',)) : ('எப்படி எப்படி இருக்கிறீர்கள்?<END>',)
# -------------------------------------------
